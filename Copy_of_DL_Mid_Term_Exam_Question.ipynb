# %% [markdown]
# <a href="https://colab.research.google.com/github/AkibHasanGH/ml-assignment-colab/blob/main/Copy_of_DL_Mid_Term_Exam_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DL Mid term exam
#
# **Name:**Akib Hasan
#
# **Course Email:
#
# ## End of Assignment
#
# Before submitting:
# - Run all cells from top to bottom.
# - Check that all answer sections are filled.
# - Instruction video অনুযায়ী আমাদের দেয়া Colab ফাইলটি থেকে প্রথম একটি Save copy in drive করে নিবা। এরপর Google colab এর মধ্যে কোডগুলো করবে এবং সেই ফাইলটি ‘Anyone with the link’ & ‘View’ Access দিয়ে ফাইলটির Shareble Link টি সাবমিট করবে।

# %% [markdown]
# # Question 01: [ Marks 10 ]
#
# Draw a Neural Network
#
# Draw a neural network with:
#
# 3 input features
#
# 3 hidden layers (at least 2 neurons each)
#
# 1 output neuron
#
# a) Label all weights and biases. <br>
# b) Write the forward equations layer by layer. <br>
# c) If output uses Sigmoid, write the final prediction equation. <br>
#
# Please note : Don't forget to attach a screen short of your neural network.

# %% [markdown]
# **Write** Answer 01:

# %% [markdown]
# Neural Network
# https://github.com/AkibHasanGH/ml-assignment-colab/blob/main/DL_MidTerm_Answering_1_picture.png

# %% [markdown]
# a) Weights and Biases
# Input → Hidden Layer 1: Weights
# 𝑤
# 𝑖
# 𝑗
# [
# 1
# ]
# , biases
# 𝑏
# 𝑗
# [
# 1
# ]
# .
#
# Hidden Layer 1 → Hidden Layer 2: Weights
# 𝑤
# 𝑖
# 𝑗
# [
# 2
# ]
# , biases
# 𝑏
# 𝑗
# [
# 2
# ]
# .
#
# Hidden Layer 2 → Hidden Layer 3: Weights
# 𝑤
# 𝑖
# 𝑗
# [
# 3
# ]
# , biases
# 𝑏
# 𝑗
# [
# 3
# ]
# .
#
# Hidden Layer 3 → Output: Weights
# 𝑤
# 𝑖
# [
# 4
# ]
# , bias
# 𝑏
# [
# 4
# ]
# .
#
# b) Forward Equations Layer by Layer
# Layer 1 (Hidden Layer 1):
#
# 𝑧
# 1
# [
# 1
# ]
# =
# 𝑤
# 11
# [
# 1
# ]
# 𝑥
# 1
# +
# 𝑤
# 21
# [
# 1
# ]
# 𝑥
# 2
# +
# 𝑤
# 31
# [
# 1
# ]
# 𝑥
# 3
# +
# 𝑏
# 1
# [
# 1
# ]
# 𝑧
# 2
# [
# 1
# ]
# =
# 𝑤
# 12
# [
# 1
# ]
# 𝑥
# 1
# +
# 𝑤
# 22
# [
# 1
# ]
# 𝑥
# 2
# +
# 𝑤
# 32
# [
# 1
# ]
# 𝑥
# 3
# +
# 𝑏
# 2
# [
# 1
# ]
# 𝑎
# 𝑗
# [
# 1
# ]
# =
# 𝑓
# (
# 𝑧
# 𝑗
# [
# 1
# ]
# )
# Layer 2 (Hidden Layer 2):
#
# 𝑧
# 𝑘
# [
# 2
# ]
# =
# ∑
# 𝑗
# 𝑤
# 𝑗
# 𝑘
# [
# 2
# ]
# 𝑎
# 𝑗
# [
# 1
# ]
# +
# 𝑏
# 𝑘
# [
# 2
# ]
# 𝑎
# 𝑘
# [
# 2
# ]
# =
# 𝑓
# (
# 𝑧
# 𝑘
# [
# 2
# ]
# )
# Layer 3 (Hidden Layer 3):
#
# 𝑧
# 𝑚
# [
# 3
# ]
# =
# ∑
# 𝑘
# 𝑤
# 𝑘
# 𝑚
# [
# 3
# ]
# 𝑎
# 𝑘
# [
# 2
# ]
# +
# 𝑏
# 𝑚
# [
# 3
# ]
# 𝑎
# 𝑚
# [
# 3
# ]
# =
# 𝑓
# (
# 𝑧
# 𝑚
# [
# 3
# ]
# )
# Output Layer:
#
# 𝑧
# [
# 4
# ]
# =
# ∑
# 𝑚
# 𝑤
# 𝑚
# [
# 4
# ]
# 𝑎
# 𝑚
# [
# 3
# ]
# +
# 𝑏
# [
# 4
# ]
# c) Final Prediction (Sigmoid Output)
# 𝑦
# ^
# =
# 𝜎
# (
# 𝑧
# [
# 4
# ]
# )
# =
# 1
# 1
# +
# 𝑒
# −
# 𝑧
# [
# 4
# ]

# %% [markdown]
#  # Question 02: [ Marks 20 ]
#
# Manual Gradient Calculation
#
# Given:
#
# z = w*x + b <br>
# y_pred = sigmoid(z) <br>
# L = −[ y log(y_pred) + (1−y) log(1−y_pred) ] <br>
#
# a) Write dL/dy_pred <br>
# b) Write dy_pred/dz <br>
# c) Show that dL/dz = y_pred − y <br>

# %% [markdown]
# ## Write Answer 02:

# %% [markdown]
# Given:
# 𝑧
# =
# 𝑤
# ⋅
# 𝑥
# +
# 𝑏
# 𝑦
# pred
# =
# 𝜎
# (
# 𝑧
# )
# =
# 1
# 1
# +
# 𝑒
# −
# 𝑧
# 𝐿
# =
# −
# [
# 𝑦
# ⋅
# log
# ⁡
# (
# 𝑦
# pred
# )
# +
# (
# 1
# −
# 𝑦
# )
# ⋅
# log
# ⁡
# (
# 1
# −
# 𝑦
# pred
# )
# ]
# a)
# 𝑑
# 𝐿
# 𝑑
# 𝑦
# pred
# Loss function
# 𝐿
#  কে
# 𝑦
# pred
#  respect‑এ differentiate করি:
#
# 𝑑
# 𝐿
# 𝑑
# 𝑦
# pred
# =
# −
# [
# 𝑦
# 𝑦
# pred
# −
# 1
# −
# 𝑦
# 1
# −
# 𝑦
# pred
# ]
# b)
# 𝑑
# 𝑦
# pred
# 𝑑
# 𝑧
# যেহেতু
# 𝑦
# pred
# =
# 𝜎
# (
# 𝑧
# )
# :
#
# 𝑑
# 𝑦
# pred
# 𝑑
# 𝑧
# =
# 𝜎
# (
# 𝑧
# )
# ⋅
# (
# 1
# −
# 𝜎
# (
# 𝑧
# )
# )
# =
# 𝑦
# pred
# (
# 1
# −
# 𝑦
# pred
# )
# c) Show that
# 𝑑
# 𝐿
# 𝑑
# 𝑧
# =
# 𝑦
# pred
# −
# 𝑦
# Chain rule ব্যবহার করি:
#
# 𝑑
# 𝐿
# 𝑑
# 𝑧
# =
# 𝑑
# 𝐿
# 𝑑
# 𝑦
# pred
# ⋅
# 𝑑
# 𝑦
# pred
# 𝑑
# 𝑧
# এখন substitute করি:
#
# 𝑑
# 𝐿
# 𝑑
# 𝑧
# =
# (
# −
# 𝑦
# 𝑦
# pred
# +
# 1
# −
# 𝑦
# 1
# −
# 𝑦
# pred
# )
# ⋅
# (
# 𝑦
# pred
# (
# 1
# −
# 𝑦
# pred
# )
# )
# Simplify করলে পাওয়া যায়:
#
# 𝑑
# 𝐿
# 𝑑
# 𝑧
# =
# 𝑦
# pred
# −
# 𝑦

# %% [markdown]
# # Question 03: [ Marks 15 ]
#
# x = 3
# y1 = x^2
# y2 = 4*x
# L = y1 + y2
#
# a) Draw the computation graph. <br>
# b) Compute dL/dx manually. <br>
# c) Explain how would you do it using Autograd <br>

# %% [markdown]
# ## Write Answer 03:

# %% [markdown]
# ![3_a_b_Answer](https://github.com/AkibHasanGH/ml-assignment-colab/blob/main/DL_Midterm_Answering_3_a_b_picture.jpeg?raw=true)

# %% [markdown]
# Autograd automatically builds the computation graph.
#
# যখন তুমি backward() চালাও, সেটা chain rule ব্যবহার করে সব intermediate derivative হিসাব করে।
#
# Final gradient
# 𝑑
# 𝐿
# 𝑑
# 𝑥
#  সরাসরি x.grad এ পাওয়া যায়।

# %% [markdown]
# # Question 04: [ Marks 15 ]
#
# Create a scalar tensor x = 3.0 with gradient tracking enabled. <br>
# Compute y = x² + 4x. <br>
# Perform backpropagation. <br>
# Print the gradient of x. <br>
#
# Write the full PyTorch code yourself. <br>

# %% [markdown]
# ## Write Answer 04:

# %%
import torch

x = torch.tensor(3.0, requires_grad=True)

y = x**2 + 4*x

y.backward()

print("Gradient of x:", x.grad)
# Out:
# Gradient of x: tensor(10.)

# %% [markdown]
# Derive
# 𝑑
# 𝑦
# 𝑑
# 𝑥
# =
# 2
# 𝑥
# +
# 4
# =
# 2
# (
# 3
# )
# +
# 4
# =
# 10

# %% [markdown]
# # Question 05: [ Marks 10 ]
#
# Create two tensors:
# w = 2.0 (requires_grad=True) <br>
# b = 1.0 (requires_grad=True) <br>
#
# Let input x = 3.0. <br>
# Compute z = w*x + b. <br>
# Use Sigmoid to get y_pred.
#  <br>
#
# Define Binary Cross Entropy manually (without built-in loss). <br>
# Compute gradients using backward(). <br>
# Print gradients of w and b. <br>
#
# Write full code.

# %% [markdown]
# ## Write Answer 05:

# %%
import torch

w = torch.tensor(2.0, requires_grad=True)
b = torch.tensor(1.0, requires_grad=True)

x = torch.tensor(3.0)

z = w * x + b

y_pred = 1 / (1 + torch.exp(-z))

y = torch.tensor(1.0)

L = -(y * torch.log(y_pred) + (1 - y) * torch.log(1 - y_pred))

L.backward()

print("Gradient of w:", w.grad.item())
print("Gradient of b:", b.grad.item())
# Out:
# Gradient of w: -0.0027331537567079067
# Gradient of b: -0.0009110512328334153

# %% [markdown]
# # Question 06: [ Marks 10 ]
#
# Create a tensor x = 2.0 (requires_grad=True). <br>
# Compute:
#
# y1 = x² <br>
# y2 = 3x <br>
# L = y1 + y2 <br>
#
# Call backward(). <br>
# Print x.grad. <br>
#
# Write full PyTorch code.

# %% [markdown]
# ## Write Answer 06:

# %%
import torch

x = torch.tensor(2.0, requires_grad=True)

y1 = x**2
y2 = 3*x
L = y1 + y2

L.backward()

print(x.grad)
# Out:
# tensor(7.)

# %% [markdown]
# # Question 07: [ Marks 20 ]
#
#
# Create tensor w = 2.0 (requires_grad=True). <br>
#
# Compute two different losses sequentially and call backward() twice. <br>
# Print w.grad. <br>
#
# Do not clear gradients. <br>
# Explain what you observe. <br>
#
# Write full code.

# %% [markdown]
# ## Write Answer 07:

# %%
import torch

w = torch.tensor(2.0, requires_grad=True)

L1 = w**2
L1.backward()

L2 = 3*w
L2.backward()

print(w.grad)
# Out:
# tensor(7.)
